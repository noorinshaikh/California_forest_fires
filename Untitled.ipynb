# %%
import pandas
df=pandas.read_excel('california_nearby_fires.xlsx',sheet_name=0)
df
# Out:
#                                    Incident                            Type  \
# 0                           Martinez 3 Fire                        Wildfire
# 1                             Hillside Fire                        Wildfire
# 2    2019 Fall Rx Burns for Flagstaff Dist.                 Prescribed Fire
# 3           2019 Malheur NF Prescribed Fire                 Prescribed Fire
# 4              Kaibab NF South Zone Rx Fire                 Prescribed Fire
# 5   Brushy Mountain/Buskirk Prescribed Burn                 Prescribed Fire
# 6                              Taboose Fire                        Wildfire
# 7                                Ranch Fire                        Wildfire
# 8                               Decker Fire                        Wildfire
# 9                               Caples Fire                        Wildfire
# 10      San Juan NF Prescribed Fire Program                 Prescribed Fire
# ...

# %%
for index, row in df.iterrows():
    print(float((row['Coordinates'].split(',')[0]).strip()))
# Out:
# 33.64
# 34.183
# 35.113
# 44.418
# 35.913
# 37.833
# 37.034
# 40.04
# 38.409
# 38.724
# 37.279
# 39.369
# 32.328
# 36.349
# 38.113
# 40.559
# 38.796
# 40.897
# 44.377
# 40.041
# 36.583
# 44.773
# 46.933
